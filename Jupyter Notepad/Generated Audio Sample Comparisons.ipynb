# %% [markdown]
# # Generated Audio Sample Comparisons
#
# In order to allow both the playback of audio and the visualization of the audio as plots we will import the following libraries:

# %%
# %matplotlib inline
import IPython
import librosa.display
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## 2 Modes: 'Zero' and 'One'
#
# The following examples compare the real data against both WaveGAN and Conditioned WaveGAN modesl.

# %% [markdown]
# ### 2-Mode: Real Data

# %% [markdown]
# #### Zeroes

# %%
directory = 'Real 2-Mode Samples/Zero/'
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file = directory + filename
        x, sr = librosa.load(file)
        plt.figure(figsize=(14, 5))
        librosa.display.waveplot(x, sr=sr)
        IPython.display.display(
            IPython.display.Audio(file)
        )
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...

# %% [markdown]
# #### Ones

# %%
directory = 'Real 2-Mode Samples/One/'
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file = directory + filename
        x, sr = librosa.load(file)
        plt.figure(figsize=(14, 5))
        librosa.display.waveplot(x, sr=sr)
        IPython.display.display(
            IPython.display.Audio(file)
        )
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...

# %% [markdown]
# ## 2-Mode: Baseline WGAN Generated Samples

# %%
directory = 'Generated WGAN 2-Mode Samples/'
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file = directory + filename
        x, sr = librosa.load(file)
        plt.figure(figsize=(14, 5))
        librosa.display.waveplot(x, sr=sr)
        IPython.display.display(
            IPython.display.Audio(file)
        )

# %% [markdown]
# ## 2-Mode Conditioned WGAN Generated Samples

# %% [markdown]
# #### Zeroes

# %% [markdown]
# #### Ones

# %% [markdown]
# ## 4 Modes: 'Up', 'Down', 'Left' and 'Right'

# %% [markdown]
# ### Real Data

# %% [markdown]
# #### Up

# %%
directory = 'Real 4-Mode Samples/Up/'
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file = directory + filename
        x, sr = librosa.load(file)
        plt.figure(figsize=(14, 5))
        librosa.display.waveplot(x, sr=sr)
        IPython.display.display(
            IPython.display.Audio(file)
        )
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...

# %% [markdown]
# #### Down

# %%
directory = 'Real 4-Mode Samples/Down/'
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file = directory + filename
        x, sr = librosa.load(file)
        plt.figure(figsize=(14, 5))
        librosa.display.waveplot(x, sr=sr)
        IPython.display.display(
            IPython.display.Audio(file)
        )
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...

# %% [markdown]
# #### Left

# %%
directory = 'Real 4-Mode Samples/Left/'
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file = directory + filename
        x, sr = librosa.load(file)
        plt.figure(figsize=(14, 5))
        librosa.display.waveplot(x, sr=sr)
        IPython.display.display(
            IPython.display.Audio(file)
        )
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...

# %% [markdown]
# #### Right

# %%
directory = 'Real 4-Mode Samples/Right/'
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file = directory + filename
        x, sr = librosa.load(file)
        plt.figure(figsize=(14, 5))
        librosa.display.waveplot(x, sr=sr)
        IPython.display.display(
            IPython.display.Audio(file)
        )
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...

# %% [markdown]
# ### Baseline WGAN Generated Samples

# %% [markdown]
# ### Conditioned WGAN Generated Samples

# %% [markdown]
# #### Up

# %% [markdown]
# #### Down

# %% [markdown]
# #### Left

# %% [markdown]
# #### Right
